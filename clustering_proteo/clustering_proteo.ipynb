# %% [markdown]
# # Clustering of proteomic data according to their UNIPROT keywords

# %% [markdown]
# - Enter the list of proteins in the file "liste_proteines.txt"
# - Enter the number of clusters below (nb_cluster)
# - Enter the number of most important keywords for each class (top)

# %%
nb_cluster=5
top=10

# %% [markdown]
# ## Library

# %%
# %pip install kmodes
# %pip install bioservices # new
import pandas as pd
import requests, sys, json
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from kmodes.kmodes import KModes

## NEW -> Uniprot library
from bioservices.uniprot import UniProt
u = UniProt(verbose = False)

from google.colab import files
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting kmodes
#   Downloading kmodes-0.12.1-py2.py3-none-any.whl (20 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.22.0 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.0.2)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.21.6)
# Requirement already satisfied: scipy>=0.13.3 in /usr/local/lib/python3.7/dist-packages (from kmodes) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.0->kmodes) (3.1.0)
# Installing collected packages: kmodes
# Successfully installed kmodes-0.12.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bioservices
#   Downloading bioservices-1.10.0.tar.gz (200 kB)
#      |████████████████████████████████| 200 kB 6.7 MB/s
# Collecting grequests
#   Downloading grequests-0.6.0-py3-none-any.whl (5.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from bioservices) (2.23.0)
# Collecting requests_cache
#   Downloading requests_cache-0.9.5-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 3.1 MB/s
# Collecting easydev>=0.9.36
#   Downloading easydev-0.12.0.tar.gz (47 kB)
#      |████████████████████████████████| 47 kB 4.4 MB/s
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bioservices) (4.6.3)
# Collecting xmltodict
#   Downloading xmltodict-0.13.0-py2.py3-none-any.whl (10.0 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from bioservices) (4.2.6)
# Collecting suds-community
#   Downloading suds_community-1.1.2-py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 14.3 MB/s
# Requirement already satisfied: appdirs in /usr/local/lib/python3.7/dist-packages (from bioservices) (1.4.4)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.7/dist-packages (from bioservices) (1.14.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from bioservices) (1.3.5)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Collecting colorama
#   Downloading colorama-0.4.5-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from easydev>=0.9.36->bioservices) (4.8.0)
# Collecting gevent
#   Downloading gevent-21.12.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.8 MB)
#      |████████████████████████████████| 5.8 MB 33.9 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from gevent->grequests->bioservices) (57.4.0)
# Collecting zope.event
#   Downloading zope.event-4.5.0-py2.py3-none-any.whl (6.8 kB)
# Collecting zope.interface
#   Downloading zope.interface-5.4.0-cp37-cp37m-manylinux2010_x86_64.whl (251 kB)
#      |████████████████████████████████| 251 kB 37.8 MB/s
# Requirement already satisfied: greenlet<2.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from gevent->grequests->bioservices) (1.1.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->bioservices) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->bioservices) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->bioservices) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->bioservices) (1.15.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->easydev>=0.9.36->bioservices) (0.7.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->bioservices) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->bioservices) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->bioservices) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->bioservices) (1.24.3)
# Collecting cattrs<=22.2,>=1.8
#   Downloading cattrs-22.1.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests_cache->bioservices) (21.4.0)
# Collecting url-normalize<2.0,>=1.4
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 11.5 MB/s
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.7/dist-packages (from cattrs<=22.2,>=1.8->requests_cache->bioservices) (4.1.1)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.0.0rc8-py3-none-any.whl (11 kB)
# Building wheels for collected packages: bioservices, easydev
#   Building wheel for bioservices (setup.py) ... done
#   Created wheel for bioservices: filename=bioservices-1.10.0-py3-none-any.whl size=230646 sha256=ec630b6afe6c03512d1283e61d8d0c861a84acbd024f9d159179901dea37c1cf
#   Stored in directory: /root/.cache/pip/wheels/52/b0/10/3f9d68c60400657f9032ec676f093fc8de0af84b71dba29cb8
#   Building wheel for easydev (setup.py) ... done
#   Created wheel for easydev: filename=easydev-0.12.0-py3-none-any.whl size=64232 sha256=48f72bf9fddb98bad0a00ead1f01b7ebdccbabef10b3032422974e2aa27bd27a
#   Stored in directory: /root/.cache/pip/wheels/82/ab/83/fdfc4017ea44a585b6754752cc5f63f2d0d63fcc1317e7174b
# Successfully built bioservices easydev
# Installing collected packages: zope.interface, zope.event, urllib3, exceptiongroup, url-normalize, gevent, colorlog, colorama, cattrs, xmltodict, suds-community, requests-cache, grequests, easydev, bioservices
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed bioservices-1.10.0 cattrs-22.1.0 colorama-0.4.5 colorlog-6.6.0 easydev-0.12.0 exceptiongroup-1.0.0rc8 gevent-21.12.0 grequests-0.6.0 requests-cache-0.9.5 suds-community-1.1.2 url-normalize-1.4.3 urllib3-1.25.11 xmltodict-0.13.0 zope.event-4.5.0 zope.interface-5.4.0
# Creating directory /root/.config/bioservices
# Creating directory /root/.cache/bioservices
# Welcome to Bioservices
# ======================
# It looks like you do not have a configuration file.
# We are creating one with default values in /root/.config/bioservices/bioservices.cfg .
# Done
# Mounted at /content/gdrive

# %% [markdown]
# ## Calling functions

# %%
# Convert Accession id to Genename

def convert_ACC_GENENAME(id) :
    convert = u.mapping(fr="UniProtKB_AC-ID", to="Gene_Name", query=id)
    return convert['results'][0]['to']

"""
def convert_ACC_GENENAME(id):
    url = 'http://www.uniprot.org/mapping/' 
    params = {'from':'ACC','to':'GENENAME','format':'tab','query':id} 
    request = requests.get(url, params)
    return request.text.split("\n")[1].split("\t")[1]
"""
# Out:
# '\ndef convert_ACC_GENENAME(id):\n    url = \'http://www.uniprot.org/mapping/\' \n    params = {\'from\':\'ACC\',\'to\':\'GENENAME\',\'format\':\'tab\',\'query\':id} \n    request = requests.get(url, params)\n    return request.text.split("\n")[1].split("\t")[1]\n'

# %%
# Create a list of proteins
list_acc=[]
with open("/content/gdrive/MyDrive/clustering_proteo/liste_proteines.txt","r") as f:
    for l in f.readlines():
        list_acc.append(l[:-1])
len(list_acc)
# Out:
# 150

# %%
# Create a dict with protein for keys and keywords for values
dico_kw={}
for i in list_acc:
    URL_api="https://www.ebi.ac.uk/proteins/api/proteins"
    query=f"/{i}"
    URL=URL_api + query
    header = {'Accept': 'application/json'}
    result=requests.get(URL,headers=header)
    data1=result.json()
    list_temp=[]
    try:
        for k in data1["keywords"]:
            list_temp.append(k["value"])
        dico_kw[i]=(list_temp)
    except:
        print(i)
len(dico_kw.keys())
# Out:
# Q9Y2J3
# O95426
# Q26875
# O15076
# P49737
# Q5ZPR4
# Q8N574
# Q96EQ1
# Q13189
# P09197
# Q8WUJ4
# Q9NQA4
# Q16364
# Q8NF92
# P08755
# Q2TAL9
# O95529
# Q8IZV6
# O15077
# Q7Z3D8
# P49738
# Q8TBB8
# Q8N575
# Q96EQ2
# P1210
# 117

# %%
# List of keywords
list_k=[]
for v in dico_kw.values():
    for v1 in v:
        if v1 not in list_k:
            list_k.append(v1)
len(list_k)
# Out:
# 244

# %%
# Create one vector for each protein with 1 if the keyword is present and 0 if not (multihot encoding)

list_prot=list(dico_kw.keys())
array=np.zeros((len(list_prot),len(list_k)))
for i in range(len(list_prot)):
    for j in range(len(list_k)): 
        if list_k[j] in dico_kw[list_prot[i]]:
            array[i][j]=1
        else:
            array[i][j]=0

# %%
df = pd.DataFrame(array, index=list_prot,columns=list_k)
#df.head()
#df.shape

# %%
# Clustering with kmean
kmeans = KMeans(n_clusters=nb_cluster, random_state=0).fit(df)

# %%
# PCA  to display the clusters on a graph
pca = PCA(n_components=2)
data=pca.fit_transform(df)

# %%
# Create a column with cluster label (0,1,2...)
df_kw=df
df_kw["cluster"]=kmeans.labels_

# %%
# Write a file with the most important keywords and the proteins  for each cluster
colormap=np.array(['Red','green','blue','orange','black','purple'])
kw=pd.read_csv("/content/gdrive/MyDrive/clustering_proteo/keywords-all.tab",sep='\t')
res=kmeans.__dict__
with open("cluster_proteine.txt","w") as f:
  for k in range(nb_cluster):
    f.write("\n\n")
    f.write("*"*50)
    f.write(f"\nClasse: {k} ({colormap[k]})\n")
    f.write("\nListe des keywords:")
    list_kw_weight=[]
    for i in np.argsort(res['cluster_centers_'][k]*-1):
      if list_k[i] not in list(kw.loc[kw["Category"]=="Technical term"]["Name"]):
        if list_k[i] not in list(kw.loc[kw["Category"]=="Coding sequence diversity"]["Name"]):
          list_kw_weight.append(list_k[i])
    for w in list_kw_weight[:top]:
        f.write(f"\n{w}")
    f.write(f"\n\nListe des protéines de la classe {k}:\n")
    for p in df_kw.index[df_kw["cluster"]==k].tolist():
      f.write(f"{p} ")
  files.download("cluster_proteine.txt")

# %% [markdown]
# ## Results

# %%
# Display the clusters
plt.scatter(data[:,0],data[:,1],c=colormap[kmeans.labels_])
plt.savefig("ACP_kw.png", format="PNG")
files.download("ACP_kw.png")
